# %% [markdown]
# # 🛡️ IronDome — Try It Yourself
#
# **Secure CLI Password Manager** with AES-256 encryption & zero-knowledge architecture.
#
# [![PyPI](https://img.shields.io/pypi/v/IronDome?style=for-the-badge&logo=pypi&logoColor=white&color=0073b7)](https://pypi.org/project/IronDome/)
# [![GitHub](https://img.shields.io/badge/GitHub-IronDome--Bunker-181717?style=for-the-badge&logo=github)](https://github.com/TheKingHippopotamus/IronDome-Bunker)
#
# ---
#
# ### How to use this notebook:
# 1. Run the **Install** cell below
# 2. Run the **Launch** cell to start the password manager
# 3. Follow the interactive prompts to create a master account and manage passwords
#
# > **Note:** Your data stays in this Colab session. Nothing is sent anywhere.

# %%
# Step 1: Install IronDome from PyPI
# !pip install IronDome -q
print("\n\u2705 IronDome installed successfully!")

import password_manager
print(f"   Version: {password_manager.__version__}")

# %%
# Step 2: Launch IronDome
# This will start the interactive CLI password manager
# !bunker

# %% [markdown]
# ---
#
# ### What you can do:
# - **Create a master account** with username & password
# - **Generate strong passwords** with customizable options
# - **Store passwords** for different websites/services
# - **Search & retrieve** stored credentials
# - **Create encrypted backups**
#
# ### Security features active in this session:
# - AES-256 encryption via Fernet
# - PBKDF2-HMAC-SHA256 with 600,000 iterations
# - Zero-knowledge master password handling
# - Brute force protection with adaptive lockouts
# - Session timeout after 30 minutes
#
# ---
#
# *Created by [King Hippopotamus](https://github.com/TheKingHippopotamus)*
